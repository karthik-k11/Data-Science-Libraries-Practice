# %% [markdown]
# ### **Pandas**
# - This notebook is for practicing pandas library
# - Almost all the pandas operations will be here

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#importing pandas library
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
print(pd.__doc__)
# Out:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
#   - Size mutability: columns can be inserted and deleted from DataFrame and
#     higher dimensional objects
#   - Automatic and explicit data alignment: objects can be explicitly aligned
# ...

# %% [markdown]
# **Series**

# %%
age = [20,25,23,30,41,12,10,15,60]
index = ['a','b','c','d','e','f','g','h','i']

series = pd.Series(data=age, index=index, name='Series')
series
# Out:
# a    20
# b    25
# c    23
# d    30
# e    41
# f    12
# g    10
# h    15
# i    60
# Name: Series, dtype: int64

# %% [markdown]
# **Data Frame**

# %%
print(pd.DataFrame.__doc__)
# Out:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
#     which have an index defined, it is aligned by its index. This alignment also
#     occurs if data is a Series or a DataFrame itself. Alignment is done on
#     Series/DataFrame inputs.
#
#     If data is a list of dicts, column order follows insertion-order.
#
# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
data ={'Name': ['Karthik', 'Virat', 'Sachin', 'Hazlewood', 'Krunal'],
        'Age': [28, 18, 13, 62, 50],
        'Department': ['HR', 'Admin', 'AI', 'Admin', 'HR'],
        'Salary': [4000,  5000, 4500, 6000, 4800]

}

df= pd.DataFrame(data)

# %%
df= pd.DataFrame(data=data)
df
# Out:
#         Name  Age Department  Salary
# 0    Karthik   28         HR    4000
# 1      Virat   18      Admin    5000
# 2     Sachin   13         AI    4500
# 3  Hazlewood   62      Admin    6000
# 4     Krunal   50         HR    4800

# %%
df.shape
# Out:
# (5, 4)

# %%
df.shape[0]  ##Rows
# Out:
# 5

# %%
df.shape[1]  #Columns
# Out:
# 4

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Department    object
# Salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df.columns[:3]
# Out:
# Index(['Name', 'Age', 'Department'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Age         5 non-null      int64
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
for col in df.columns:
    print(f"{col} : {df[col].unique()}")
# Out:
# Name : ['Karthik' 'Virat' 'Sachin' 'Hazlewood' 'Krunal']
# Age : [28 18 13 62 50]
# Department : ['HR' 'Admin' 'AI']
# Salary : [4000 5000 4500 6000 4800]

# %%
df.nunique()
# Out:
# Name          5
# Age           5
# Department    3
# Salary        5
# dtype: int64

# %%
df.Age.nsmallest()
# Out:
# 2    13
# 1    18
# 0    28
# 4    50
# 3    62
# Name: Age, dtype: int64

# %%
df.Age.nlargest()
# Out:
# 3    62
# 4    50
# 0    28
# 1    18
# 2    13
# Name: Age, dtype: int64

# %%
df.describe()
# Out:
#              Age       Salary
# count   5.000000     5.000000
# mean   34.200000  4860.000000
# std    21.052316   740.270221
# min    13.000000  4000.000000
# 25%    18.000000  4500.000000
# 50%    28.000000  4800.000000
# 75%    50.000000  5000.000000
# max    62.000000  6000.000000

# %%
df.describe().T   ##Transpose
# Out:
#         count    mean         std     min     25%     50%     75%     max
# Age       5.0    34.2   21.052316    13.0    18.0    28.0    50.0    62.0
# Salary    5.0  4860.0  740.270221  4000.0  4500.0  4800.0  5000.0  6000.0

# %%
df.describe(include='object').T
# Out:
#            count unique      top freq
# Name           5      5  Karthik    1
# Department     5      3       HR    2

# %% [markdown]
# **Data Manipulation**

# %%
df.head()
# Out:
#         Name  Age Department  Salary
# 0    Karthik   28         HR    4000
# 1      Virat   18      Admin    5000
# 2     Sachin   13         AI    4500
# 3  Hazlewood   62      Admin    6000
# 4     Krunal   50         HR    4800

# %%
df.tail()
# Out:
#         Name  Age Department  Salary
# 0    Karthik   28         HR    4000
# 1      Virat   18      Admin    5000
# 2     Sachin   13         AI    4500
# 3  Hazlewood   62      Admin    6000
# 4     Krunal   50         HR    4800

# %%
## Selecting columns
## Single column
df['Name']
# Out:
# 0      Karthik
# 1        Virat
# 2       Sachin
# 3    Hazlewood
# 4       Krunal
# Name: Name, dtype: object

# %%
## Selecting multiple columns
df[['Name', 'Age']]
# Out:
#         Name  Age
# 0    Karthik   28
# 1      Virat   18
# 2     Sachin   13
# 3  Hazlewood   62
# 4     Krunal   50

# %%
## Using dot notation
df.Age
# Out:
# 0    28
# 1    18
# 2    13
# 3    62
# 4    50
# Name: Age, dtype: int64

# %%
col = df.columns[:4]
df[col]
# Out:
#         Name  Age Department  Salary
# 0    Karthik   28         HR    4000
# 1      Virat   18      Admin    5000
# 2     Sachin   13         AI    4500
# 3  Hazlewood   62      Admin    6000
# 4     Krunal   50         HR    4800

# %%
df[1:3]
# Out:
#      Name  Age Department  Salary
# 1   Virat   18      Admin    5000
# 2  Sachin   13         AI    4500

# %%
df[1:10:2]
# Out:
#         Name  Age Department  Salary
# 1      Virat   18      Admin    5000
# 3  Hazlewood   62      Admin    6000

# %%
## To select Rows
## loc:- label based
df.loc[0]
# Out:
# Name          Karthik
# Age                28
# Department         HR
# Salary           4000
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#       Name  Age Department  Salary
# 0  Karthik   28         HR    4000
# 1    Virat   18      Admin    5000
# 2   Sachin   13         AI    4500

# %%
# Select rows 1 to 3 and specific columns
df.loc[1:3, ['Name', 'Salary']]
# Out:
#         Name  Salary
# 1      Virat    5000
# 2     Sachin    4500
# 3  Hazlewood    6000

# %%
## iloc:- Position Based
df.iloc[0]
# Out:
# Name          Karthik
# Age                28
# Department         HR
# Salary           4000
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# Out:
#       Name  Age Department  Salary
# 0  Karthik   28         HR    4000
# 1    Virat   18      Admin    5000
# 2   Sachin   13         AI    4500

# %%
## Let's see for iris data
import seaborn as sns
df1= sns.load_dataset('iris')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.loc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df1.loc[0:2]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.loc[1:3, ['sepal_length', 'sepal_width']]
# Out:
#    sepal_length  sepal_width
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1

# %%
df1.iloc[0:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.iloc[::2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [75 rows x 5 columns]

# %%
df1.iloc[::3]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 12            4.8          3.0           1.4          0.1      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 21            5.1          3.7           1.5          0.4      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 27            5.2          3.5           1.5          0.2      setosa
# 30            4.8          3.1           1.6          0.2      setosa
# 33            5.5          4.2           1.4          0.2      setosa
# ...

# %%
df1.iloc[4:10:1]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
## First three rows and first 2 columns
df1.iloc[0:3, 0:2]
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
df1.iloc[0:5:3]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
df1.iloc[1:5, 1:4]
# Out:
#    sepal_width  petal_length  petal_width
# 1          3.0           1.4          0.2
# 2          3.2           1.3          0.2
# 3          3.1           1.5          0.2
# 4          3.6           1.4          0.2

# %%
df[df['Salary']>4500]
# Out:
#         Name  Age Department  Salary
# 1      Virat   18      Admin    5000
# 3  Hazlewood   62      Admin    6000
# 4     Krunal   50         HR    4800

# %%
df1[df1['sepal_length']>5.0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %%
df1[df1['petal_length']>5.0]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 83            6.0          2.7           5.1          1.6  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 102           7.1          3.0           5.9          2.1   virginica
# 103           6.3          2.9           5.6          1.8   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 107           7.3          2.9           6.3          1.8   virginica
# 108           6.7          2.5           5.8          1.8   virginica
# 109           7.2          3.6           6.1          2.5   virginica
# 110           6.5          3.2           5.1          2.0   virginica
# 111           6.4          2.7           5.3          1.9   virginica
# ...

# %%
df1.query('sepal_length > 5')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %%
query_test = df1.query('sepal_length > 5 and species == "setosa"')
print(query_test.head())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa

# %%
df1[df1['species'] == 'setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df1[(df1['sepal_length'] > 5) & (df1['species'] == 'virginica')]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# ...

# %%
df1[(df1['petal_width'] > 2.5) | (df1['species'] == 'versicolor')]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %% [markdown]
# **isin**

# %%
df1[df1['species'].isin(['virginica','versicolor'])]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
# 149           5.9          3.0           5.1          1.8   virginica
#
# [100 rows x 5 columns]

# %%
## Multi Indexing
employee = [
    ['HR', 'HR', 'IT', 'IT'],
    ['Karthik', 'Kumar', 'Siraj', 'Jithesh']
]
index = pd.MultiIndex.from_arrays(employee, names=('Department', 'Name'))
multi_df = pd.DataFrame({'Salary': [4000, 4200, 5000, 5500]}, index=index)

multi_df
# Out:
#                     Salary
# Department Name
# HR         Karthik    4000
#            Kumar      4200
# IT         Siraj      5000
#            Jithesh    5500

# %%
multi_df.loc['HR']
# Out:
#          Salary
# Name
# Karthik    4000
# Kumar      4200

# %%
multi_df.loc[('IT','Siraj')]
# Out:
# Salary    5000
# Name: (IT, Siraj), dtype: int64

# %%
## Cross section 
multi_df.xs('IT')
# Out:
#          Salary
# Name
# Siraj      5000
# Jithesh    5500

# %%
filtered= df1[df1['species'].isin(['setosa', 'virginica'])]
filtered
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [100 rows x 5 columns]

# %%
filtered_r= df1[df1['sepal_length'].between(5,6)]
filtered_r
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 119           6.0          2.2           5.0          1.5  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [67 rows x 5 columns]

# %%
filtered_s= df1[df1['species'].str.contains('vir')]
filtered_s
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
## To use isna() Im making first row species value as None
df1.loc[0, 'species']=None
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2    None
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
missing= df1[df1['species'].isna()]
missing
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2    None

# %%
value= df1.at[1, 'species']
value
# Out:
# 'setosa'

# %%
value1= df1.iat[1, 0]
value1
# Out:
# np.float64(4.9)

# %%
result= df1['sepal_length'].where(df1['sepal_length']>5)
result
# Out:
# 0      5.1
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
result1= df1['sepal_length'].mask(df1['sepal_length']>5)
result1
# Out:
# 0      NaN
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    NaN
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# Name: sepal_length, Length: 150, dtype: float64

# %% [markdown]
# **Modifying Values**

# %%
data1 = {
    'Name': [
        'Virat Kohli', 'Rohit Sharma', 'MS Dhoni', 'KL Rahul',
        'Hardik Pandya', 'Jasprit Bumrah', 'Ravindra Jadeja',
        'Shubman Gill', 'Rishabh Pant', 'Suryakumar Yadav',
        'Rishabh Pant', 'Suryakumar Yadav', 'Ravindra Jadeja', 'Shubman Gill'
    ],
    
    'Age': [
        35, 36, 42, 32,
        31, 30, None,
        25, 27, 33,
        27, 33, 34, 25
    ],
    
    'City': [
        'Mumbai', 'Delhi', 'Chennai', 'Bengaluru',
        'Ahmedabad', 'Madhya Pradesh', 'Pune',
        'Kolkata', 'Delhi', 'Mumbai',
        'Delhi', 'Mumbai', 'Pune', 'Kolkata'
    ],
    
    'Salary': [
        1850000, 1750000, 2100000, 1500000,
        1600000, 1700000, 1550000,
        1400000, 1450000, 1650000,
        1450000, 1650000, 1550000, None
    ],
    
    'Date': [
        '2024-06-01', '2024-06-02', '2024-06-03', '2024-06-04',
        '2024-06-05', '2024-06-06', '2024-06-07', '2024-06-08',
        '2024-06-09', '2024-06-10', '2024-06-09', '2024-06-10',
        '2024-06-07', '2024-06-08'
    ],
    
    'Category': [
        'X', 'Y', 'Z', 'X',
        'Y', 'X', 'Z', 'Y',
        'X', 'Y', 'X', 'Y',
        None, 'Y'
    ]
}

# %%
df2 = pd.DataFrame(data=data1)
df2
# Out:
#                 Name   Age            City     Salary        Date Category
# 0        Virat Kohli  35.0          Mumbai  1850000.0  2024-06-01        X
# 1       Rohit Sharma  36.0           Delhi  1750000.0  2024-06-02        Y
# 2           MS Dhoni  42.0         Chennai  2100000.0  2024-06-03        Z
# 3           KL Rahul  32.0       Bengaluru  1500000.0  2024-06-04        X
# 4      Hardik Pandya  31.0       Ahmedabad  1600000.0  2024-06-05        Y
# 5     Jasprit Bumrah  30.0  Madhya Pradesh  1700000.0  2024-06-06        X
# 6    Ravindra Jadeja   NaN            Pune  1550000.0  2024-06-07        Z
# 7       Shubman Gill  25.0         Kolkata  1400000.0  2024-06-08        Y
# 8       Rishabh Pant  27.0           Delhi  1450000.0  2024-06-09        X
# 9   Suryakumar Yadav  33.0          Mumbai  1650000.0  2024-06-10        Y
# 10      Rishabh Pant  27.0           Delhi  1450000.0  2024-06-09        X
# ...

# %%
df2['Name'][2]
# Out:
# 'MS Dhoni'

# %%
print(f"Before Modifying : {df2['Name'][2]}")

df2['Name'][2] = 'Dhoni'

print(f"After Modifying : {df2['Name'][2]}")
# Out:
# Before Modifying : MS Dhoni
# After Modifying : Dhoni

# %%
df2.loc[2]
# Out:
# Name             Dhoni
# Age               42.0
# City           Chennai
# Salary       2100000.0
# Date        2024-06-03
# Category             Z
# Name: 2, dtype: object

# %% [markdown]
# **String methods**

# %%
df2[df2['City'].str.contains('chennai', case=False)]
# Out:
#     Name   Age     City     Salary        Date Category
# 2  Dhoni  42.0  Chennai  2100000.0  2024-06-03        Z

# %%
df2['City'].str.split(' ')
# Out:
# 0              [Mumbai]
# 1               [Delhi]
# 2             [Chennai]
# 3           [Bengaluru]
# 4           [Ahmedabad]
# 5     [Madhya, Pradesh]
# 6                [Pune]
# 7             [Kolkata]
# 8               [Delhi]
# 9              [Mumbai]
# 10              [Delhi]
# 11             [Mumbai]
# 12               [Pune]
# 13            [Kolkata]
# Name: City, dtype: object

# %%
df2['City'].str.split(' ').str.get(0)
# Out:
# 0        Mumbai
# 1         Delhi
# 2       Chennai
# 3     Bengaluru
# 4     Ahmedabad
# 5        Madhya
# 6          Pune
# 7       Kolkata
# 8         Delhi
# 9        Mumbai
# 10        Delhi
# 11       Mumbai
# 12         Pune
# 13      Kolkata
# Name: City, dtype: object

# %%
df2[df2['Name'].str.startswith('S')]
# Out:
#                 Name   Age     City     Salary        Date Category
# 7       Shubman Gill  25.0  Kolkata  1400000.0  2024-06-08        Y
# 9   Suryakumar Yadav  33.0   Mumbai  1650000.0  2024-06-10        Y
# 11  Suryakumar Yadav  33.0   Mumbai  1650000.0  2024-06-10        Y
# 13      Shubman Gill  25.0  Kolkata        NaN  2024-06-08        Y

# %%
df2[df2['Name'].str.endswith('l')]
# Out:
#             Name   Age       City     Salary        Date Category
# 3       KL Rahul  32.0  Bengaluru  1500000.0  2024-06-04        X
# 7   Shubman Gill  25.0    Kolkata  1400000.0  2024-06-08        Y
# 13  Shubman Gill  25.0    Kolkata        NaN  2024-06-08        Y

# %%
df2['City1'] = df2['City'].str.upper()
df2['City1']
# Out:
# 0             MUMBAI
# 1              DELHI
# 2            CHENNAI
# 3          BENGALURU
# 4          AHMEDABAD
# 5     MADHYA PRADESH
# 6               PUNE
# 7            KOLKATA
# 8              DELHI
# 9             MUMBAI
# 10             DELHI
# 11            MUMBAI
# 12              PUNE
# 13           KOLKATA
# Name: City1, dtype: object

# %%
df2['Name1'] = df2['Name'].str.lower()
df2['Name1']
# Out:
# 0          virat kohli
# 1         rohit sharma
# 2                dhoni
# 3             kl rahul
# 4        hardik pandya
# 5       jasprit bumrah
# 6      ravindra jadeja
# 7         shubman gill
# 8         rishabh pant
# 9     suryakumar yadav
# 10        rishabh pant
# 11    suryakumar yadav
# 12     ravindra jadeja
# 13        shubman gill
# Name: Name1, dtype: object

# %%
df2['Name1'] = df2['Name'].str.capitalize()
df2['Name1']
# Out:
# 0          Virat kohli
# 1         Rohit sharma
# 2                Dhoni
# 3             Kl rahul
# 4        Hardik pandya
# 5       Jasprit bumrah
# 6      Ravindra jadeja
# 7         Shubman gill
# 8         Rishabh pant
# 9     Suryakumar yadav
# 10        Rishabh pant
# 11    Suryakumar yadav
# 12     Ravindra jadeja
# 13        Shubman gill
# Name: Name1, dtype: object

# %%
df2['Name'].str.count('Hannah').sum()
# Out:
# np.int64(0)

# %%
df2['Name'].add(' Mr')
# Out:
# 0          Virat Kohli Mr
# 1         Rohit Sharma Mr
# 2                Dhoni Mr
# 3             KL Rahul Mr
# 4        Hardik Pandya Mr
# 5       Jasprit Bumrah Mr
# 6      Ravindra Jadeja Mr
# 7         Shubman Gill Mr
# 8         Rishabh Pant Mr
# 9     Suryakumar Yadav Mr
# 10        Rishabh Pant Mr
# 11    Suryakumar Yadav Mr
# 12     Ravindra Jadeja Mr
# 13        Shubman Gill Mr
# Name: Name, dtype: object

# %%
df2['City'] = df2['City'].str.replace('Bengaluru','Karnataka')
df2['City']
# Out:
# 0             Mumbai
# 1              Delhi
# 2            Chennai
# 3          Karnataka
# 4          Ahmedabad
# 5     Madhya Pradesh
# 6               Pune
# 7            Kolkata
# 8              Delhi
# 9             Mumbai
# 10             Delhi
# 11            Mumbai
# 12              Pune
# 13           Kolkata
# Name: City, dtype: object

# %% [markdown]
# ### **Data Cleaning**

# %%
data = pd.DataFrame({
    'A': [10, 22, None, 45, None, 67, 78, 10, 999],
    'B': [5, None, 15, None, 25, None, 300, 5, 5]
})

data
# Out:
#        A      B
# 0   10.0    5.0
# 1   22.0    NaN
# 2    NaN   15.0
# 3   45.0    NaN
# 4    NaN   25.0
# 5   67.0    NaN
# 6   78.0  300.0
# 7   10.0    5.0
# 8  999.0    5.0

# %%
##Missing values
data.isnull().sum()
# Out:
# A    2
# B    3
# dtype: int64

# %%
data.isna().sum()
# Out:
# A    2
# B    3
# dtype: int64

# %%
data.notnull().sum()
# Out:
# A    7
# B    6
# dtype: int64

# %%
data.notna().sum()
# Out:
# A    7
# B    6
# dtype: int64

# %%
##Finding duplicates
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
##Finding Outlier
def find_outlier(df, columns):
    outlier_indices = set()
    
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lf = Q1 - 1.5 * IQR
        uf = Q3 + 1.5 * IQR
        col_outliers = df[(df[col] < lf) | (df[col] > uf)]
        outlier_indices.update(col_outliers.index)
        
    return df.loc[list(outlier_indices)]

outliers = find_outlier(data, ['A', 'B'])
print(outliers)
# Out:
#        A      B
# 8  999.0    5.0
# 6   78.0  300.0

# %% [markdown]
# **Handling missing values**

# %%
##In a specific column
dropna = data.dropna()
dropna
# Out:
#        A      B
# 0   10.0    5.0
# 6   78.0  300.0
# 7   10.0    5.0
# 8  999.0    5.0

# %%
round(data['A'].mean(), 2)
# Out:
# np.float64(175.86)

# %%
data['A'].fillna(round(data['A'].mean(), 2))
# Out:
# 0     10.00
# 1     22.00
# 2    175.86
# 3     45.00
# 4    175.86
# 5     67.00
# 6     78.00
# 7     10.00
# 8    999.00
# Name: A, dtype: float64

# %%
data['B'].fillna(round(data['B'].mean(), 2))
# Out:
# 0      5.00
# 1     59.17
# 2     15.00
# 3     59.17
# 4     25.00
# 5     59.17
# 6    300.00
# 7      5.00
# 8      5.00
# Name: B, dtype: float64

# %%
data['A']
# Out:
# 0     10.0
# 1     22.0
# 2      NaN
# 3     45.0
# 4      NaN
# 5     67.0
# 6     78.0
# 7     10.0
# 8    999.0
# Name: A, dtype: float64

# %%
##Replace with average of surrouding values
data['A'].interpolate()
# Out:
# 0     10.0
# 1     22.0
# 2     33.5
# 3     45.0
# 4     56.0
# 5     67.0
# 6     78.0
# 7     10.0
# 8    999.0
# Name: A, dtype: float64

# %% [markdown]
# **Handling Duplicate Values**

# %%
data[data.duplicated()]
# Out:
#       A    B
# 7  10.0  5.0

# %%
data.drop_duplicates().reset_index(drop=True)
# Out:
#        A      B
# 0   10.0    5.0
# 1   22.0    NaN
# 2    NaN   15.0
# 3   45.0    NaN
# 4    NaN   25.0
# 5   67.0    NaN
# 6   78.0  300.0
# 7  999.0    5.0

# %% [markdown]
# **Handling the outlier**

# %%
##Dropping
data.dropna(inplace=True)
data
# Out:
#        A      B
# 0   10.0    5.0
# 6   78.0  300.0
# 7   10.0    5.0
# 8  999.0    5.0

# %%
##Finding Outlier
def remove_outlier(df, columns):

    Cleaned_df = df.copy()
    
    for col in columns:
        Q1 = Cleaned_df[col].quantile(0.25)
        Q3 = Cleaned_df[col].quantile(0.75)
        IQR = Q3 - Q1
        lf = Q1 - 1.5 * IQR
        uf = Q3 + 1.5 * IQR
        
        Cleaned_df = Cleaned_df[(Cleaned_df[col] >= lf) & (Cleaned_df[col] <= uf)]
        
    return Cleaned_df

outliers = remove_outlier(data, ['A', 'B'])
print(outliers)
# Out:
#       A      B
# 0  10.0    5.0
# 6  78.0  300.0
# 7  10.0    5.0

# %%
Q1 = data['B'].quantile(0.25)
Q1
# Out:
# np.float64(5.0)

# %%
Q3 = data['B'].quantile(0.75)
Q3
# Out:
# np.float64(78.75)

# %%
IQR = Q3-Q1
lf = Q1 - 1.5 * IQR
lf
# Out:
# np.float64(-105.625)

# %%
uf = Q3 + 1.5 * IQR
uf
# Out:
# np.float64(189.375)

# %%
import numpy as np

def log_transformation(df, columns):
    
    tranform_df = df.copy()

    for col in columns:
        tranform_df[col] = np.log1p(tranform_df[col]) 
    return tranform_df

log = log_transformation(data, ['A', 'B'])
log
# Out:
#           A         B
# 0  2.397895  1.791759
# 6  4.369448  5.707110
# 7  2.397895  1.791759
# 8  6.907755  1.791759

# %%
df2
# Out:
#                 Name   Age            City     Salary        Date Category  \
# 0        Virat Kohli  35.0          Mumbai  1850000.0  2024-06-01        X
# 1       Rohit Sharma  36.0           Delhi  1750000.0  2024-06-02        Y
# 2              Dhoni  42.0         Chennai  2100000.0  2024-06-03        Z
# 3           KL Rahul  32.0       Karnataka  1500000.0  2024-06-04        X
# 4      Hardik Pandya  31.0       Ahmedabad  1600000.0  2024-06-05        Y
# 5     Jasprit Bumrah  30.0  Madhya Pradesh  1700000.0  2024-06-06        X
# 6    Ravindra Jadeja   NaN            Pune  1550000.0  2024-06-07        Z
# 7       Shubman Gill  25.0         Kolkata  1400000.0  2024-06-08        Y
# 8       Rishabh Pant  27.0           Delhi  1450000.0  2024-06-09        X
# 9   Suryakumar Yadav  33.0          Mumbai  1650000.0  2024-06-10        Y
# 10      Rishabh Pant  27.0           Delhi  1450000.0  2024-06-09        X
# ...

# %%
df2.isnull().sum()
# Out:
# Name        0
# Age         1
# City        0
# Salary      1
# Date        0
# Category    1
# City1       0
# Name1       0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(2)

# %%
df2['Age'].fillna(round(df2['Age'].mean(), 2), inplace=True)
df2['Salary'].fillna(round(df2['Salary'].mean(), 2), inplace=True)
df2['Category'].fillna(df2['Category'].mode()[0], inplace = True)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2
# Out:
#                 Name    Age            City      Salary        Date Category  \
# 0        Virat Kohli  35.00          Mumbai  1850000.00  2024-06-01        X
# 1       Rohit Sharma  36.00           Delhi  1750000.00  2024-06-02        Y
# 2              Dhoni  42.00         Chennai  2100000.00  2024-06-03        Z
# 3           KL Rahul  32.00       Karnataka  1500000.00  2024-06-04        X
# 4      Hardik Pandya  31.00       Ahmedabad  1600000.00  2024-06-05        Y
# 5     Jasprit Bumrah  30.00  Madhya Pradesh  1700000.00  2024-06-06        X
# 6    Ravindra Jadeja  31.54            Pune  1550000.00  2024-06-07        Z
# 7       Shubman Gill  25.00         Kolkata  1400000.00  2024-06-08        Y
# 8       Rishabh Pant  27.00           Delhi  1450000.00  2024-06-09        X
# 9   Suryakumar Yadav  33.00          Mumbai  1650000.00  2024-06-10        Y
# 12   Ravindra Jadeja  34.00            Pune  1550000.00  2024-06-07        Y
# ...

# %%
df2= df2.reset_index(drop=True)

# %% [markdown]
# ### **Data Transformation**

# %%
df2.rename(columns={'Name':"Full Name"}, inplace =True)

# %%
df2['Age'] = df2['Age'].astype('int')

# %%
df2['City'].replace({"Mumbai":"Maharashtra"}, inplace=True)

# %%
df2
# Out:
#            Full Name  Age            City      Salary        Date Category  \
# 0        Virat Kohli   35     Maharashtra  1850000.00  2024-06-01        X
# 1       Rohit Sharma   36           Delhi  1750000.00  2024-06-02        Y
# 2              Dhoni   42         Chennai  2100000.00  2024-06-03        Z
# 3           KL Rahul   32       Karnataka  1500000.00  2024-06-04        X
# 4      Hardik Pandya   31       Ahmedabad  1600000.00  2024-06-05        Y
# 5     Jasprit Bumrah   30  Madhya Pradesh  1700000.00  2024-06-06        X
# 6    Ravindra Jadeja   31            Pune  1550000.00  2024-06-07        Z
# 7       Shubman Gill   25         Kolkata  1400000.00  2024-06-08        Y
# 8       Rishabh Pant   27           Delhi  1450000.00  2024-06-09        X
# 9   Suryakumar Yadav   33     Maharashtra  1650000.00  2024-06-10        Y
# 10   Ravindra Jadeja   34            Pune  1550000.00  2024-06-07        Y
# ...

# %%
def Catgorize(col):
    if col < 18:
        return "Young"
    elif col < 35:
        return "Adult"
    elif col < 55:
        return "Middle Age"
    else:
        return "Senior"

# %%
df2['Age Category'] = df2['Age'].apply(Catgorize)
df2
# Out:
#            Full Name  Age            City      Salary        Date Category  \
# 0        Virat Kohli   35     Maharashtra  1850000.00  2024-06-01        X
# 1       Rohit Sharma   36           Delhi  1750000.00  2024-06-02        Y
# 2              Dhoni   42         Chennai  2100000.00  2024-06-03        Z
# 3           KL Rahul   32       Karnataka  1500000.00  2024-06-04        X
# 4      Hardik Pandya   31       Ahmedabad  1600000.00  2024-06-05        Y
# 5     Jasprit Bumrah   30  Madhya Pradesh  1700000.00  2024-06-06        X
# 6    Ravindra Jadeja   31            Pune  1550000.00  2024-06-07        Z
# 7       Shubman Gill   25         Kolkata  1400000.00  2024-06-08        Y
# 8       Rishabh Pant   27           Delhi  1450000.00  2024-06-09        X
# 9   Suryakumar Yadav   33     Maharashtra  1650000.00  2024-06-10        Y
# 10   Ravindra Jadeja   34            Pune  1550000.00  2024-06-07        Y
# ...

# %%
data2 = pd.DataFrame({"A":[1,2,3],"B":[4,5,6]}) 
data2
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
data2.applymap(lambda x: x **2)
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %% [markdown]
# ### **Data Aggregation**

# %%
df2.dtypes
# Out:
# Full Name        object
# Age               int64
# City             object
# Salary          float64
# Date             object
# Category         object
# City1            object
# Name1            object
# Age Category     object
# dtype: object

# %%
sum_of_Salary = df2['Salary'].sum()
sum_of_Salary
# Out:
# np.float64(19730769.23)

# %%
min_Salary = df2['Salary'].min()
min_Salary
# Out:
# np.float64(1400000.0)

# %%
max_Salary = df['Salary'].max()
max_Salary
# Out:
# np.int64(6000)

# %%
avg_Age = round(df2['Age'].mean())
avg_Age
# Out:
# 32

# %%
mid_Age = round(df2['Age'].median())
mid_Age
# Out:
# 32

# %%
most_occured = df2['Category'].mode()
most_occured
# Out:
# 0    Y
# Name: Category, dtype: object

# %%
Standard_Age = df2['Age'].std()
Standard_Age
# Out:
# np.float64(4.84533515118126)

# %%
var_Age = df2['Age'].var()
var_Age
# Out:
# np.float64(23.477272727272727)

# %%
np.sqrt(var_Age) == Standard_Age
# Out:
# np.True_

# %%
df2['Category'][df2['Category'] == 'B'].count()
# Out:
# np.int64(0)

# %%
df2[df2['Category'] == 'B']['Category'].count()
# Out:
# np.int64(0)

# %%
df2['Age'].idxmax()
# Out:
# 2

# %%
df2['Age'].idxmin()
# Out:
# 7

# %%
df2['Age'].sort_values(ascending=True)
# Out:
# 7     25
# 11    25
# 8     27
# 5     30
# 4     31
# 6     31
# 3     32
# 9     33
# 10    34
# 0     35
# 1     36
# 2     42
# Name: Age, dtype: int64

# %%
df2['Age'].rank(ascending=True)
# Out:
# 0     10.0
# 1     11.0
# 2     12.0
# 3      7.0
# 4      5.5
# 5      4.0
# 6      5.5
# 7      1.5
# 8      3.0
# 9      8.0
# 10     9.0
# 11     1.5
# Name: Age, dtype: float64

# %%
df2[df2['Age'].between(35,60)]
# Out:
#       Full Name  Age         City     Salary        Date Category    City1  \
# 0   Virat Kohli   35  Maharashtra  1850000.0  2024-06-01        X   MUMBAI
# 1  Rohit Sharma   36        Delhi  1750000.0  2024-06-02        Y    DELHI
# 2         Dhoni   42      Chennai  2100000.0  2024-06-03        Z  CHENNAI
#
#           Name1 Age Category
# 0   Virat kohli   Middle Age
# 1  Rohit sharma   Middle Age
# 2         Dhoni   Middle Age

# %%
df2
# Out:
#            Full Name  Age            City      Salary        Date Category  \
# 0        Virat Kohli   35     Maharashtra  1850000.00  2024-06-01        X
# 1       Rohit Sharma   36           Delhi  1750000.00  2024-06-02        Y
# 2              Dhoni   42         Chennai  2100000.00  2024-06-03        Z
# 3           KL Rahul   32       Karnataka  1500000.00  2024-06-04        X
# 4      Hardik Pandya   31       Ahmedabad  1600000.00  2024-06-05        Y
# 5     Jasprit Bumrah   30  Madhya Pradesh  1700000.00  2024-06-06        X
# 6    Ravindra Jadeja   31            Pune  1550000.00  2024-06-07        Z
# 7       Shubman Gill   25         Kolkata  1400000.00  2024-06-08        Y
# 8       Rishabh Pant   27           Delhi  1450000.00  2024-06-09        X
# 9   Suryakumar Yadav   33     Maharashtra  1650000.00  2024-06-10        Y
# 10   Ravindra Jadeja   34            Pune  1550000.00  2024-06-07        Y
# ...

# %%
df2['Age'].add(1)
# Out:
# 0     36
# 1     37
# 2     43
# 3     33
# 4     32
# 5     31
# 6     32
# 7     26
# 8     28
# 9     34
# 10    35
# 11    26
# Name: Age, dtype: int64

# %%
df2['Age'].subtract(1)
# Out:
# 0     34
# 1     35
# 2     41
# 3     31
# 4     30
# 5     29
# 6     30
# 7     24
# 8     26
# 9     32
# 10    33
# 11    24
# Name: Age, dtype: int64

# %%
df2['Age'].multiply(2)
# Out:
# 0     70
# 1     72
# 2     84
# 3     64
# 4     62
# 5     60
# 6     62
# 7     50
# 8     54
# 9     66
# 10    68
# 11    50
# Name: Age, dtype: int64

# %%
df2['Age'].div(2)
# Out:
# 0     17.5
# 1     18.0
# 2     21.0
# 3     16.0
# 4     15.5
# 5     15.0
# 6     15.5
# 7     12.5
# 8     13.5
# 9     16.5
# 10    17.0
# 11    12.5
# Name: Age, dtype: float64

# %%
df2['Age'].mod(2)
# Out:
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# Name: Age, dtype: int64

# %%
df2[df2['Age'].ge(35)]
# Out:
#       Full Name  Age         City     Salary        Date Category    City1  \
# 0   Virat Kohli   35  Maharashtra  1850000.0  2024-06-01        X   MUMBAI
# 1  Rohit Sharma   36        Delhi  1750000.0  2024-06-02        Y    DELHI
# 2         Dhoni   42      Chennai  2100000.0  2024-06-03        Z  CHENNAI
#
#           Name1 Age Category
# 0   Virat kohli   Middle Age
# 1  Rohit sharma   Middle Age
# 2         Dhoni   Middle Age

# %%
df2['Category'].value_counts().index
# Out:
# Index(['Y', 'X', 'Z'], dtype='object', name='Category')

# %%
df2['Category'].value_counts().values
# Out:
# array([6, 4, 2])

# %%
df2
# Out:
#            Full Name  Age            City      Salary        Date Category  \
# 0        Virat Kohli   35     Maharashtra  1850000.00  2024-06-01        X
# 1       Rohit Sharma   36           Delhi  1750000.00  2024-06-02        Y
# 2              Dhoni   42         Chennai  2100000.00  2024-06-03        Z
# 3           KL Rahul   32       Karnataka  1500000.00  2024-06-04        X
# 4      Hardik Pandya   31       Ahmedabad  1600000.00  2024-06-05        Y
# 5     Jasprit Bumrah   30  Madhya Pradesh  1700000.00  2024-06-06        X
# 6    Ravindra Jadeja   31            Pune  1550000.00  2024-06-07        Z
# 7       Shubman Gill   25         Kolkata  1400000.00  2024-06-08        Y
# 8       Rishabh Pant   27           Delhi  1450000.00  2024-06-09        X
# 9   Suryakumar Yadav   33     Maharashtra  1650000.00  2024-06-10        Y
# 10   Ravindra Jadeja   34            Pune  1550000.00  2024-06-07        Y
# ...

# %%
df2[df2['Category'] == "X"]
# Out:
#         Full Name  Age            City     Salary        Date Category  \
# 0     Virat Kohli   35     Maharashtra  1850000.0  2024-06-01        X
# 3        KL Rahul   32       Karnataka  1500000.0  2024-06-04        X
# 5  Jasprit Bumrah   30  Madhya Pradesh  1700000.0  2024-06-06        X
# 8    Rishabh Pant   27           Delhi  1450000.0  2024-06-09        X
#
#             City1           Name1 Age Category
# 0          MUMBAI     Virat kohli   Middle Age
# 3       BENGALURU        Kl rahul        Adult
# 5  MADHYA PRADESH  Jasprit bumrah        Adult
# 8           DELHI    Rishabh pant        Adult

# %%
df2.groupby('Category')['Salary'].max()
# Out:
# Category
# X    1850000.0
# Y    1750000.0
# Z    2100000.0
# Name: Salary, dtype: float64

# %%
city_wise_salary = df2.groupby('City')['Salary'].sum()
city_wise_salary
# Out:
# City
# Ahmedabad         1600000.00
# Chennai           2100000.00
# Delhi             3200000.00
# Karnataka         1500000.00
# Kolkata           3030769.23
# Madhya Pradesh    1700000.00
# Maharashtra       3500000.00
# Pune              3100000.00
# Name: Salary, dtype: float64

# %%
city_wise_salary.index
# Out:
# Index(['Ahmedabad', 'Chennai', 'Delhi', 'Karnataka', 'Kolkata',
#        'Madhya Pradesh', 'Maharashtra', 'Pune'],
#       dtype='object', name='City')

# %%
city_wise_salary.values
# Out:
# array([1600000.  , 2100000.  , 3200000.  , 1500000.  , 3030769.23,
#        1700000.  , 3500000.  , 3100000.  ])

# %%
df2.groupby('City').agg({'Age':'mean'})
# Out:
#                  Age
# City
# Ahmedabad       31.0
# Chennai         42.0
# Delhi           31.5
# Karnataka       32.0
# Kolkata         25.0
# Madhya Pradesh  30.0
# Maharashtra     34.0
# Pune            32.5

# %%
df2.groupby(['Category','Age Category']).agg({"Salary":"sum"}).sort_values(by='Salary', ascending=False).reset_index()
# Out:
#   Category Age Category      Salary
# 0        Y        Adult  7830769.23
# 1        X        Adult  4650000.00
# 2        Z   Middle Age  2100000.00
# 3        X   Middle Age  1850000.00
# 4        Y   Middle Age  1750000.00
# 5        Z        Adult  1550000.00

# %%
df2.groupby(['Category','Age Category']).agg({"Salary":"sum", "Age":'mean'}).reset_index()
# Out:
#   Category Age Category      Salary        Age
# 0        X        Adult  4650000.00  29.666667
# 1        X   Middle Age  1850000.00  35.000000
# 2        Y        Adult  7830769.23  29.600000
# 3        Y   Middle Age  1750000.00  36.000000
# 4        Z        Adult  1550000.00  31.000000
# 5        Z   Middle Age  2100000.00  42.000000

# %%
category_salary_age = df2.groupby('Age Category').agg({"Salary":["min", "max"], "Age":["min", "max"]})
category_salary_age
# Out:
#                  Salary            Age
#                     min        max min max
# Age Category
# Adult         1400000.0  1700000.0  25  34
# Middle Age    1750000.0  2100000.0  35  42

# %%
category_salary_age.unstack()
# Out:
#              Age Category
# Salary  min  Adult           1400000.0
#              Middle Age      1750000.0
#         max  Adult           1700000.0
#              Middle Age      2100000.0
# Age     min  Adult                25.0
#              Middle Age           35.0
#         max  Adult                34.0
#              Middle Age           42.0
# dtype: float64

# %%
Numarical = df2.select_dtypes(include=['int', 'float']).columns.tolist()
Categorical = df2.select_dtypes(exclude=['int', 'float']).columns.tolist()
print("Numerical Columns: ", Numarical)
print("Categorical Columns: ", Categorical)
# Out:
# Numerical Columns:  ['Age', 'Salary']
# Categorical Columns:  ['Full Name', 'City', 'Date', 'Category', 'City1', 'Name1', 'Age Category']
